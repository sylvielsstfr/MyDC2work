# %% [markdown]
# # Compute Cl on galaxy overdensities on DC2-Data
#
# - author : Sylvie Dagoret-Campagne
# - affliliation : IJCLab/in2p3/CNRS
# - creation date : July 28th 2020
# - update : January 30th 2021
#
# - Run on Spark cluster

# %%
# %matplotlib inline

import os

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pyarrow

# %%
pyarrow.__version__
# Out:
# '0.14.1'

# %%
#from pyspark import SparkContext
#import pyspark
#sc = SparkContext (
#   "local", 
#   "storagelevel app"
#)

# %%
# Verify SparkContext
print(sc)

# Print Spark version
print(sc.version)
# Out:
# <SparkContext master=mesos://vm-75063.lal.in2p3.fr:5050 appName=PySparkShell>
# 2.4.4

# %%
from pyspark.sql.functions import col, pandas_udf 
from pyspark.sql.types import LongType

from pyspark.sql.types import IntegerType,FloatType
from pyspark.sql.functions import pandas_udf, PandasUDFType

# %%
# here is how we create a function ('Ang2Pix') that can be called by dataframes
# it takes as input the "ra" and "dec" values (which are not very different from theta/phi)
# and returns the pixel number (but as pandas series for efficiency)
import numpy as np
import pandas as pd
import healpy as hp

nside=512

# %%
npix = hp.nside2npix(nside)
lmax = 3 * nside

# %%
def Ang2Pix_func(ra: pd.Series, dec: pd.Series) -> pd.Series:
    return pd.Series(hp.ang2pix(nside,np.radians(90-dec),np.radians(ra)))

# %%
pd_ang2pix = pandas_udf(Ang2Pix_func, returnType=IntegerType())
#gal = gal.withColumn("ihealpix",pd_ang2pix(gal["RA"],gal["DEC"]))

# %% [markdown]
# ## Get parquet files

# %%
#! hadoop dfs -ls /lsst/DC2

# %%
! hadoop dfs -ls /lsst/DC2
# Out:
# DEPRECATED: Use of this script to execute hdfs command is deprecated.
# Instead use the hdfs command for it.
#
# Found 22 items
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2020-06-12 10:23 /lsst/DC2/DR6axCdc2.parquet
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2020-12-11 12:11 /lsst/DC2/cosmoDC2
# -rw-r--r--   3 stephane.plaszczynski lsst 83486737444 2020-05-28 19:33 /lsst/DC2/dc2_object_run2.2i_dr3.parquet
# -rw-r--r--   3 stephane.plaszczynski lsst 44384598496 2020-06-05 13:15 /lsst/DC2/dc2_object_run2.2i_dr6.parquet
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2021-01-06 01:06 /lsst/DC2/dc2_object_run2.2i_dr6_wfd_prev2
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2020-10-07 20:49 /lsst/DC2/dc2_object_run2.2i_dr6_wfd_v1
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2020-06-26 10:36 /lsst/DC2/dc2_object_run2.2i_dr6b
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2020-07-28 18:46 /lsst/DC2/dc2_object_run2.2i_dr6c
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2020-09-07 11:52 /lsst/DC2/dc2_object_run2.2i_dr6d
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2019-10-21 15:54 /lsst/DC2/df1.parquet
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2019-11-08 16:58 /lsst/DC2/df2.parquet
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2019-12-06 18:48 /lsst/DC2/df3.parquet
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2019-12-10 11:35 /lsst/DC2/df4.parquet
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2019-09-24 11:18 /lsst/DC2/object_catalog
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2019-12-13 15:52 /lsst/DC2/refcatXobj.parquet
# -rw-r--r--   3 stephane.plaszczynski lsst  3628146240 2019-12-09 19:05 /lsst/DC2/refcat_v3_dc2_r2p1i.fits
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2019-12-13 13:48 /lsst/DC2/refcat_v3_dc2_r2p1i.parquet
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2020-06-08 15:29 /lsst/DC2/run21xstars.parquet
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2020-06-09 13:03 /lsst/DC2/run22xCdc2_r0.5.parquet
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2020-06-08 17:21 /lsst/DC2/run22xstars.parquet
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2021-01-28 11:59 /lsst/DC2/skysim5000
# drwxr-xr-x   - stephane.plaszczynski lsst           0 2019-12-13 13:39 /lsst/DC2/starsXcosmoDC2.parquet

# %% [markdown]
# ### Index file to get the list of files to read

# %%
#file_index='ListOfFiles_dc2_object_run2.2i_dr6c.txt'
file_index='/home/sylvie.dagoret-campagne/desc/MyDC2work/cluster-spark/ListOfFilesfilt_dc2_object_run2.2i_dr6c.txt'

# %%
# Pandas does not read correctly the files
#pd_list=pd.read_table(file_index,header=None,index_col=None)

# %%
#with pd.option_context('display.max_rows', None, 'display.max_columns', 128):
#    print(pd_list)

# %% [markdown]
# ### read the index ascii file line by line

# %%
all_files=[]
with open(file_index) as fp:
   theline = fp.readline()
   cnt = 1
   while theline:
       print("Line {}: {}".format(cnt, theline.strip()))
       all_files.append(theline.strip()) 
       theline = fp.readline()
       cnt += 1
# Out:
# Line 1: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2731.parquet
# Line 2: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2729.parquet
# Line 3: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2728.parquet
# Line 4: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2734.parquet
# Line 5: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2732.parquet
# Line 6: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2733.parquet
# Line 7: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2725.parquet
# Line 8: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2726.parquet
# Line 9: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2730.parquet
# Line 10: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2724.parquet
# Line 11: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2727.parquet
# Line 12: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2735.parquet
# Line 13: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2896.parquet
# Line 14: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2723.parquet
# Line 15: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2897.parquet
# Line 16: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2898.parquet
# Line 17: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2899.parquet
# Line 18: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2903.parquet
# Line 19: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2901.parquet
# Line 20: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2902.parquet
# Line 21: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2900.parquet
# Line 22: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3074.parquet
# Line 23: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2908.parquet
# Line 24: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2906.parquet
# Line 25: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2905.parquet
# Line 26: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2907.parquet
# Line 27: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2904.parquet
# Line 28: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3075.parquet
# Line 29: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3077.parquet
# Line 30: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3078.parquet
# Line 31: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3076.parquet
# Line 32: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3080.parquet
# Line 33: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3079.parquet
# Line 34: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3086.parquet
# Line 35: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3084.parquet
# Line 36: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3085.parquet
# Line 37: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3083.parquet
# Line 38: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3081.parquet
# Line 39: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3082.parquet
# Line 40: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3256.parquet
# Line 41: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3259.parquet
# Line 42: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3260.parquet
# Line 43: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3258.parquet
# Line 44: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3257.parquet
# Line 45: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3265.parquet
# Line 46: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3263.parquet
# Line 47: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3264.parquet
# Line 48: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3262.parquet
# Line 49: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3261.parquet
# Line 50: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3441.parquet
# Line 51: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3268.parquet
# Line 52: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3267.parquet
# Line 53: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3266.parquet
# Line 54: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3442.parquet
# Line 55: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3443.parquet
# Line 56: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3444.parquet
# Line 57: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3448.parquet
# Line 58: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3449.parquet
# Line 59: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3445.parquet
# Line 60: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3446.parquet
# Line 61: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3447.parquet
# Line 62: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3454.parquet
# Line 63: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3631.parquet
# Line 64: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3453.parquet
# Line 65: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3452.parquet
# Line 66: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3450.parquet
# Line 67: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3451.parquet
# Line 68: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3632.parquet
# Line 69: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3633.parquet
# Line 70: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3634.parquet
# Line 71: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3635.parquet
# Line 72: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3640.parquet
# Line 73: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3639.parquet
# Line 74: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3638.parquet
# Line 75: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3636.parquet
# Line 76: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3637.parquet
# Line 77: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3825.parquet
# Line 78: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3643.parquet
# Line 79: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3641.parquet
# Line 80: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3642.parquet
# Line 81: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3826.parquet
# Line 82: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3827.parquet
# Line 83: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3828.parquet
# Line 84: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3831.parquet
# Line 85: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3830.parquet
# Line 86: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3829.parquet
# Line 87: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3833.parquet
# Line 88: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3834.parquet
# Line 89: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3835.parquet
# Line 90: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3832.parquet
# Line 91: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3837.parquet
# Line 92: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4022.parquet
# Line 93: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4023.parquet
# Line 94: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3836.parquet
# Line 95: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4025.parquet
# Line 96: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4024.parquet
# Line 97: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4026.parquet
# Line 98: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4030.parquet
# Line 99: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4031.parquet
# Line 100: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4027.parquet
# Line 101: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4028.parquet
# Line 102: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4029.parquet
# Line 103: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4035.parquet
# Line 104: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4224.parquet
# Line 105: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4034.parquet
# Line 106: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4033.parquet
# Line 107: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4032.parquet
# Line 108: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4225.parquet
# Line 109: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4228.parquet
# Line 110: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4230.parquet
# Line 111: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4229.parquet
# Line 112: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4227.parquet
# Line 113: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4226.parquet
# Line 114: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4236.parquet
# Line 115: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4235.parquet
# Line 116: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4233.parquet
# Line 117: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4234.parquet
# Line 118: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4232.parquet
# Line 119: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4231.parquet
# Line 120: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4429.parquet
# Line 121: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4432.parquet
# Line 122: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4430.parquet
# Line 123: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4431.parquet
# Line 124: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4437.parquet
# Line 125: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4436.parquet
# Line 126: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4435.parquet
# Line 127: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4434.parquet
# Line 128: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4433.parquet
# Line 129: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4636.parquet
# Line 130: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4441.parquet
# Line 131: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4440.parquet
# Line 132: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4439.parquet
# Line 133: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4438.parquet
# Line 134: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4637.parquet
# Line 135: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4638.parquet
# Line 136: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4642.parquet
# Line 137: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4639.parquet
# Line 138: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4640.parquet
# Line 139: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4641.parquet
# Line 140: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4648.parquet
# Line 141: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4647.parquet
# Line 142: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4644.parquet
# Line 143: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4645.parquet
# Line 144: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4646.parquet
# Line 145: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4643.parquet
# Line 146: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4854.parquet
# Line 147: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4853.parquet
# Line 148: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4852.parquet
# Line 149: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4851.parquet
# Line 150: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4855.parquet
# Line 151: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4856.parquet
# Line 152: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4858.parquet
# Line 153: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4857.parquet
# Line 154: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4860.parquet
# Line 155: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract5067.parquet
# Line 156: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract5070.parquet
# Line 157: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract5071.parquet
# Line 158: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract5068.parquet
# Line 159: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract5069.parquet
# Line 160: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract5066.parquet
# Line 161: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract5065.parquet
# Line 162: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract4859.parquet
# Line 163: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract5074.parquet
# Line 164: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract5072.parquet
# Line 165: /lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract5073.parquet

# %%
all_files[:5]
# Out:
# ['/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2731.parquet',
#  '/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2729.parquet',
#  '/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2728.parquet',
#  '/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2734.parquet',
#  '/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2732.parquet']

# %% [markdown]
# ### Read files with spark

# %%
# read many files
FLAG_ONE_FILE_INPUT = False

# %%
datafile="/lsst/DC2/dc2_object_run2.2i_dr6.parquet"

# %%
datafiles=["/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2723.parquet",
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2724.parquet",
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2725.parquet",
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2726.parquet",
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2727.parquet",
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2728.parquet",
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2729.parquet",
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2730.parquet",
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2731.parquet", 
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2732.parquet", 
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2733.parquet", 
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2734.parquet", 
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2735.parquet", 
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2896.parquet",
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2897.parquet", 
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2898.parquet", 
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2897.parquet", 
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2900.parquet", 
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2901.parquet",
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2902.parquet", 
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2903.parquet", 
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2904.parquet", 
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2905.parquet", 
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2906.parquet", 
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2907.parquet",
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract2908.parquet",
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3074.parquet",
           "/lsst/DC2/dc2_object_run2.2i_dr6c/dc2_object_run2.2i_dr6c_tract3075.parquet"
          ]

# %%
base_dir="/lsst/DC2/dc2_object_run2.2i_dr6c"

# %%
from pyspark.sql import SparkSession

# Initialise our Spark session
spark = SparkSession.builder.getOrCreate()

# %%
# Read the data as DataFrame
if FLAG_ONE_FILE_INPUT:
    df = spark.read.format("parquet").load(datafile)
else: # read all files
    #the_list_of_files=os.listdir(base_dir)
    #the_sorted_list_of_files=sorted(the_list_of_files)
    #print("sorted files : ",the_sorted_list_of_files[:5])
    #selected_files=[]
    #for filename in the_sorted_list_of_files:
    #    sel_filename=re.findall("^dc2_object_run2.2i_dr6c_tract[0-9][0-9][0-9][0-9].parquet$",filename)
    #    if len(sel_filename) > 0:
    #        selected_files.append(sel_filename[0])
    #print("selected files : ", selected_files[:5])
    #InputPath = [base_dir + "/{}".format(filename) for filename in selected_files]
    InputPath = all_files  # filename from the decoded index file
    df = spark.read.parquet(*InputPath)

# %%
df = df.repartition(df.rdd.getNumPartitions())

# %% [markdown]
# ### DC2 Object catalog Schema

# %%
# Check what we have in the file
df.printSchema()
# Out:
# root
#  |-- mag_z: double (nullable = true)
#  |-- psFluxErr_y: double (nullable = true)
#  |-- cModelFlux_flag_r: boolean (nullable = true)
#  |-- IxxPSF_i: double (nullable = true)
#  |-- snr_g_cModel: double (nullable = true)
#  |-- psFlux_u: double (nullable = true)
#  |-- psFluxErr_r: double (nullable = true)
#  |-- IxxPSF_u: double (nullable = true)
#  |-- magerr_r: double (nullable = true)
#  |-- psFlux_i: double (nullable = true)
#  |-- cModelFluxErr_z: double (nullable = true)
#  |-- psFlux_flag_y: boolean (nullable = true)
#  |-- x: double (nullable = true)
#  |-- cModelFlux_flag_i: boolean (nullable = true)
#  |-- I_flag_g: boolean (nullable = true)
#  |-- Iyy_y: double (nullable = true)
#  |-- mag_g_cModel: double (nullable = true)
#  |-- psf_fwhm_g: double (nullable = true)
#  |-- IxyPSF_y: double (nullable = true)
#  |-- Iyy_g: double (nullable = true)
#  |-- psf_fwhm_y: double (nullable = true)
#  |-- xy_flag: boolean (nullable = true)
#  |-- cModelFlux_i: double (nullable = true)
#  |-- Iyy_i: double (nullable = true)
#  |-- magerr_z: double (nullable = true)
#  |-- mag_y: double (nullable = true)
#  |-- magerr_i: double (nullable = true)
#  |-- snr_z_cModel: double (nullable = true)
#  |-- good: boolean (nullable = true)
#  |-- IxyPSF_z: double (nullable = true)
#  |-- cModelFluxErr_r: double (nullable = true)
#  |-- cModelFluxErr_g: double (nullable = true)
#  |-- psFlux_g: double (nullable = true)
#  |-- IxyPSF_i: double (nullable = true)
#  |-- Iyy_z: double (nullable = true)
#  |-- psFlux_z: double (nullable = true)
#  |-- IxxPSF_y: double (nullable = true)
#  |-- Ixy_r: double (nullable = true)
#  |-- magerr_g: double (nullable = true)
#  |-- extendedness: double (nullable = true)
#  |-- blendedness: double (nullable = true)
#  |-- IxyPSF_r: double (nullable = true)
#  |-- Ixx_i: double (nullable = true)
#  |-- IyyPSF_u: double (nullable = true)
#  |-- Ixx_r: double (nullable = true)
#  |-- IxxPSF: double (nullable = true)
#  |-- Iyy_r: double (nullable = true)
#  |-- Ixy_g: double (nullable = true)
#  |-- dec: double (nullable = true)
#  |-- IyyPSF: double (nullable = true)
#  |-- cModelFlux_flag_u: boolean (nullable = true)
#  |-- psFluxErr_i: double (nullable = true)
#  |-- Ixy_i: double (nullable = true)
#  |-- objectId: long (nullable = true)
#  |-- magerr_r_cModel: double (nullable = true)
#  |-- mag_r: double (nullable = true)
#  |-- magerr_u: double (nullable = true)
#  |-- mag_z_cModel: double (nullable = true)
#  |-- Ixy: double (nullable = true)
#  |-- yErr: float (nullable = true)
#  |-- I_flag_u: boolean (nullable = true)
#  |-- psFlux_flag_g: boolean (nullable = true)
#  |-- psf_fwhm_u: double (nullable = true)
#  |-- IyyPSF_z: double (nullable = true)
#  |-- psNdata: float (nullable = true)
#  |-- mag_r_cModel: double (nullable = true)
#  |-- IyyPSF_y: double (nullable = true)
#  |-- Ixy_z: double (nullable = true)
#  |-- I_flag_i: boolean (nullable = true)
#  |-- snr_i_cModel: double (nullable = true)
#  |-- cModelFlux_z: double (nullable = true)
#  |-- magerr_y: double (nullable = true)
#  |-- psf_fwhm_r: double (nullable = true)
#  |-- magerr_i_cModel: double (nullable = true)
#  |-- Ixy_u: double (nullable = true)
#  |-- psf_fwhm_i: double (nullable = true)
#  |-- cModelFluxErr_y: double (nullable = true)
#  |-- psf_fwhm_z: double (nullable = true)
#  |-- psFlux_flag_r: boolean (nullable = true)
#  |-- psFlux_flag_i: boolean (nullable = true)
#  |-- snr_y_cModel: double (nullable = true)
#  |-- IxxPSF_r: double (nullable = true)
#  |-- Iyy: double (nullable = true)
#  |-- mag_g: double (nullable = true)
#  |-- IxxPSF_z: double (nullable = true)
#  |-- magerr_z_cModel: double (nullable = true)
#  |-- psFlux_flag_u: boolean (nullable = true)
#  |-- cModelFlux_u: double (nullable = true)
#  |-- IyyPSF_r: double (nullable = true)
#  |-- cModelFlux_flag_g: boolean (nullable = true)
#  |-- cModelFlux_y: double (nullable = true)
#  |-- psFlux_y: double (nullable = true)
#  |-- snr_u_cModel: double (nullable = true)
#  |-- Ixx_u: double (nullable = true)
#  |-- Ixx_z: double (nullable = true)
#  |-- I_flag: boolean (nullable = true)
#  |-- mag_u_cModel: double (nullable = true)
#  |-- psFlux_r: double (nullable = true)
#  |-- clean: boolean (nullable = true)
#  |-- cModelFlux_g: double (nullable = true)
#  |-- magerr_y_cModel: double (nullable = true)
#  |-- ra: double (nullable = true)
#  |-- cModelFlux_flag_y: boolean (nullable = true)
#  |-- tract: long (nullable = true)
#  |-- IxyPSF: double (nullable = true)
#  |-- mag_u: double (nullable = true)
#  |-- mag_y_cModel: double (nullable = true)
#  |-- parentObjectId: long (nullable = true)
#  |-- xErr: float (nullable = true)
#  |-- psFluxErr_g: double (nullable = true)
#  |-- snr_r_cModel: double (nullable = true)
#  |-- patch: string (nullable = true)
#  |-- magerr_g_cModel: double (nullable = true)
#  |-- Ixx: double (nullable = true)
#  |-- psFlux_flag_z: boolean (nullable = true)
#  |-- IxyPSF_g: double (nullable = true)
#  |-- cModelFluxErr_i: double (nullable = true)
#  |-- cModelFlux_r: double (nullable = true)
#  |-- Iyy_u: double (nullable = true)
#  |-- mag_i_cModel: double (nullable = true)
#  |-- IxyPSF_u: double (nullable = true)
#  |-- IyyPSF_i: double (nullable = true)
#  |-- I_flag_y: boolean (nullable = true)
#  |-- psFluxErr_u: double (nullable = true)
#  |-- Ixy_y: double (nullable = true)
#  |-- y: double (nullable = true)
#  |-- Ixx_y: double (nullable = true)
#  |-- IxxPSF_g: double (nullable = true)
#  |-- Ixx_g: double (nullable = true)
#  |-- cModelFlux_flag_z: boolean (nullable = true)
#  |-- I_flag_z: boolean (nullable = true)
#  |-- I_flag_r: boolean (nullable = true)
#  |-- magerr_u_cModel: double (nullable = true)
#  |-- IyyPSF_g: double (nullable = true)
#  |-- psFluxErr_z: double (nullable = true)
#  |-- cModelFluxErr_u: double (nullable = true)
#  |-- mag_i: double (nullable = true)

# %% [markdown]
# # Select Galaxies

# %%
df_gal=df.filter('extendedness == true')

# %%
# Show all available tracts
df_gal.select('tract').distinct().show()
# Out:
# +-----+
# |tract|
# +-----+
# | 2906|
# | 3452|
# | 3081|
# | 3640|
# | 2900|
# | 4028|
# | 4235|
# | 4636|
# | 2724|
# | 3634|
# | 3076|
# | 3636|
# | 4639|
# | 4859|
# | 3258|
# | 4229|
# | 4436|
# | 4231|
# | 4034|
# | 2908|
# +-----+
# only showing top 20 rows

# %% [markdown]
# # Get a track and show the 2D plot

# %% [markdown]
# ## utilisation de select / where /collect

# %%
mydata=df_gal.select('ra','dec').where('tract==4636').collect()
# 'collect' return a list of [ra,dec]
ra,dec=np.transpose(mydata)

# Plot a 2D histogram of sources
plt.figure(figsize=(10,7))
plt.hist2d(ra,dec,100)
#plt.gca().set_aspect('equal')
plt.colorbar(label="Number of objects")
plt.xlabel('RA [deg]')
plt.ylabel('dec [deg]')
# Out:
# Text(0, 0.5, 'dec [deg]')

# %% [markdown]
# ## Avec SQL

# %%
# Pure SQL
cols = "ra,dec"

# SQL - register first DataFrame
df_gal.createOrReplaceTempView('full_tract')


# Keep only columns with 0 < magerr_g < 0.3

sql_command = """
     SELECT {}
     from full_tract
     WHERE
           tract == 4034
""".format(cols)

# Execute the expression - return a dataframe

df_sub=spark.sql(sql_command)
mydata = df_sub.collect()

# %% [markdown]
# ## Spark DataFrame build-in methods

# %%
# using select,where
mydata=df.select('ra','dec').where('tract==4030').collect()

# or using select/filter
mydata=df.select('ra','dec').filter('tract==4030').collect()

# %% [markdown]
# ## Data type
#
# The data returned by collecting a DataFrame (collect) in Spark is structured as a native Python list of Row

# %%
print("Data type is {}".format(type(mydata[0])))
# Out:
# Data type is <class 'pyspark.sql.types.Row'>

# %%
print("Data example is {}".format(mydata[0]))
# Out:
# Data example is Row(ra=63.977987558794574, dec=-34.70781015846176)

# %% [markdown]
# ## can convert the Pyspark SQL Row into a numpy array

# %%
#arow=data[0]

# %%
#mylist=list(arow)

# %%
#print("Input type  {} / Output type {} ".format(type(arow),type(mylist)))

# %% [markdown]
# ## Implicit conversion into numpy array

# %%
#cols = np.transpose(arow)

# %%
#print("Input type  {} / Output type {} ".format(type(arow),type(cols)))

# %% [markdown]
# ## Spark to Pandas DataFrame

# %%
pdata=df_gal.select('ra','dec').where('tract=4034').toPandas()
pdata.head()
# Out:
#           ra        dec
# 0  71.712332 -34.834687
# 1  70.842557 -35.155219
# 2  71.725408 -34.420284
# 3  70.967374 -34.873969
# 4  71.606866 -35.285447

# %% [markdown]
# ## Access time

# %%
df_radec=df_gal.select('ra','dec')
# %time mydata = df_radec.where('tract==4430').collect()
# Out:
# CPU times: user 2.51 s, sys: 138 ms, total: 2.65 s
# Wall time: 10 s

# %%
# need more executors
#%time mydata = df_radec.collect()

# %% [markdown]
# ## Count

# %%
# %time mydata = df_radec.where('tract==4430').count()
# Out:
# CPU times: user 107 ms, sys: 43.1 ms, total: 150 ms
# Wall time: 6.83 s

# %%
# %time mydata = df_radec.count()
# Out:
# CPU times: user 2.42 ms, sys: 2.1 ms, total: 4.52 ms
# Wall time: 7.73 s

# %% [markdown]
# ## Applying filters and cuts

# %%
df_cut=df_radec.where('tract==4430 AND good')
df_full=df_radec.where('tract==4430')

# %%
print("Number of sources before cut : {}".format(df_full.count()))
# Out:
# Number of sources before cut : 873954

# %%
print("Number of sources after cut : {}".format(df_cut.count()))
# Out:
# Number of sources after cut : 872850

# %% [markdown]
# ## Plot the results in the standard way

# %%
plt.figure(figsize=(15,7))

for index, dataframe in enumerate([df_full,df_cut]):
    ra,dec=np.transpose(dataframe.collect())
    plt.subplot(121+index)
    (count,xe,ye,Image)=plt.hist2d(ra,dec,256);
    plt.gca().set_aspect('equal');
    plt.xlabel('RA [dec]');
    plt.ylabel('dec [dec]');
    if index ==0:
        plt.title('Full sample');
    else:
        plt.title('clean sample');
        
    plt.colorbar(label="Number of objects");

# %% [markdown]
# **Spark point of view: distribute the computation (and plot!)**
#
# The way to be faster is to distribute the plot (or the computation which leads to the data to be plotted).
# Histograms are particularly easy to distribute. Let's write a method to be apply on each Spark partition (each would contain only a fraction of the data):

# %%
def hist2d(partition, nbins=256, xyrange=None):
    """ Produce 2D histograms from (x, y) data
    
    Parameters
    ----------
    partition : Iterator
        Iterator containing partition data *[x, y].
        
    Returns
    ----------
    Generator yielding counts for each partition. 
    Counts is an array of dimension nbins x nbins.
    """
    # Unwrap the iterator
    radec = [*partition]
    ra, dec = np.transpose(radec)
    
    (counts, xedges, yedges, Image) = plt.hist2d(
        ra, dec, nbins, 
        range=xyrange)
    
    yield counts

# %%
# Min/Max values - just to make a nice plot
xyrange = [[np.min(xe), np.max(xe)], [np.min(ye), np.max(ye)]]

plt.figure(figsize=(15, 7))
for index, dataframe in enumerate([df_full, df_cut]):
    plt.subplot(121 + index)
    # This is the crucial part - build the plot data in parallel!
    im = dataframe\
        .rdd\
        .mapPartitions(lambda partition: hist2d(partition, 256, xyrange))\
        .reduce(lambda x, y: x+y)
    
    plt.imshow(im.T, origin='lower' ,extent=np.array(xyrange).flatten(),aspect='equal');
    plt.xlabel('RA [deg]');
    plt.ylabel('dec [deg]');
    if index == 0:
        plt.title('Full sample');
    else:
        plt.title('Clean objects');
    plt.colorbar(label='Number of objects');

# %%
np.array(xyrange).flatten()
# Out:
# array([ 53.04348056,  54.78260365, -32.72727263, -31.23967398])

# %% [markdown]
# ## Time access

# %%
# %time data = df_cut.collect()
# Out:
# CPU times: user 2.95 s, sys: 101 ms, total: 3.05 s
# Wall time: 3.62 s

# %%
# %time data = df_cut.rdd.mapPartitions(lambda partition: hist2d(partition, xyrange)).reduce(lambda x, y: x+y)
# Out:
# CPU times: user 214 ms, sys: 61.6 ms, total: 276 ms
# Wall time: 4.31 s

# %% [markdown]
# # Example of filtering: Star/galaxy separation

# %% [markdown]
# For now, we have `extendedness == base_ClassificationExtendedness_value` as a tool for star/galaxy classification. An object is considered extended if the the difference between the `PSF` magnitude and the [`CModel` magnitude](https://www.sdss.org/dr12/algorithms/magnitudes/#cmodel) is beyond certain threshold (0.0164). To know more about this see [Bosch et al. 2018](http://adsabs.harvard.edu/abs/2018PASJ...70S...5B) section 4.9.10
#
# **Note** JP writing: I couldn't find the counterpart of `{band}_modelfit_CModel_flux` in dpdd files. So just for the sake of the exercise, I used `magerr_{band}_cModel`.

# %%
df.printSchema()
# Out:
# root
#  |-- mag_z: double (nullable = true)
#  |-- psFluxErr_y: double (nullable = true)
#  |-- cModelFlux_flag_r: boolean (nullable = true)
#  |-- IxxPSF_i: double (nullable = true)
#  |-- snr_g_cModel: double (nullable = true)
#  |-- psFlux_u: double (nullable = true)
#  |-- psFluxErr_r: double (nullable = true)
#  |-- IxxPSF_u: double (nullable = true)
#  |-- magerr_r: double (nullable = true)
#  |-- psFlux_i: double (nullable = true)
#  |-- cModelFluxErr_z: double (nullable = true)
#  |-- psFlux_flag_y: boolean (nullable = true)
#  |-- x: double (nullable = true)
#  |-- cModelFlux_flag_i: boolean (nullable = true)
#  |-- I_flag_g: boolean (nullable = true)
#  |-- Iyy_y: double (nullable = true)
#  |-- mag_g_cModel: double (nullable = true)
#  |-- psf_fwhm_g: double (nullable = true)
#  |-- IxyPSF_y: double (nullable = true)
#  |-- Iyy_g: double (nullable = true)
#  |-- psf_fwhm_y: double (nullable = true)
#  |-- xy_flag: boolean (nullable = true)
#  |-- cModelFlux_i: double (nullable = true)
#  |-- Iyy_i: double (nullable = true)
#  |-- magerr_z: double (nullable = true)
#  |-- mag_y: double (nullable = true)
#  |-- magerr_i: double (nullable = true)
#  |-- snr_z_cModel: double (nullable = true)
#  |-- good: boolean (nullable = true)
#  |-- IxyPSF_z: double (nullable = true)
#  |-- cModelFluxErr_r: double (nullable = true)
#  |-- cModelFluxErr_g: double (nullable = true)
#  |-- psFlux_g: double (nullable = true)
#  |-- IxyPSF_i: double (nullable = true)
#  |-- Iyy_z: double (nullable = true)
#  |-- psFlux_z: double (nullable = true)
#  |-- IxxPSF_y: double (nullable = true)
#  |-- Ixy_r: double (nullable = true)
#  |-- magerr_g: double (nullable = true)
#  |-- extendedness: double (nullable = true)
#  |-- blendedness: double (nullable = true)
#  |-- IxyPSF_r: double (nullable = true)
#  |-- Ixx_i: double (nullable = true)
#  |-- IyyPSF_u: double (nullable = true)
#  |-- Ixx_r: double (nullable = true)
#  |-- IxxPSF: double (nullable = true)
#  |-- Iyy_r: double (nullable = true)
#  |-- Ixy_g: double (nullable = true)
#  |-- dec: double (nullable = true)
#  |-- IyyPSF: double (nullable = true)
#  |-- cModelFlux_flag_u: boolean (nullable = true)
#  |-- psFluxErr_i: double (nullable = true)
#  |-- Ixy_i: double (nullable = true)
#  |-- objectId: long (nullable = true)
#  |-- magerr_r_cModel: double (nullable = true)
#  |-- mag_r: double (nullable = true)
#  |-- magerr_u: double (nullable = true)
#  |-- mag_z_cModel: double (nullable = true)
#  |-- Ixy: double (nullable = true)
#  |-- yErr: float (nullable = true)
#  |-- I_flag_u: boolean (nullable = true)
#  |-- psFlux_flag_g: boolean (nullable = true)
#  |-- psf_fwhm_u: double (nullable = true)
#  |-- IyyPSF_z: double (nullable = true)
#  |-- psNdata: float (nullable = true)
#  |-- mag_r_cModel: double (nullable = true)
#  |-- IyyPSF_y: double (nullable = true)
#  |-- Ixy_z: double (nullable = true)
#  |-- I_flag_i: boolean (nullable = true)
#  |-- snr_i_cModel: double (nullable = true)
#  |-- cModelFlux_z: double (nullable = true)
#  |-- magerr_y: double (nullable = true)
#  |-- psf_fwhm_r: double (nullable = true)
#  |-- magerr_i_cModel: double (nullable = true)
#  |-- Ixy_u: double (nullable = true)
#  |-- psf_fwhm_i: double (nullable = true)
#  |-- cModelFluxErr_y: double (nullable = true)
#  |-- psf_fwhm_z: double (nullable = true)
#  |-- psFlux_flag_r: boolean (nullable = true)
#  |-- psFlux_flag_i: boolean (nullable = true)
#  |-- snr_y_cModel: double (nullable = true)
#  |-- IxxPSF_r: double (nullable = true)
#  |-- Iyy: double (nullable = true)
#  |-- mag_g: double (nullable = true)
#  |-- IxxPSF_z: double (nullable = true)
#  |-- magerr_z_cModel: double (nullable = true)
#  |-- psFlux_flag_u: boolean (nullable = true)
#  |-- cModelFlux_u: double (nullable = true)
#  |-- IyyPSF_r: double (nullable = true)
#  |-- cModelFlux_flag_g: boolean (nullable = true)
#  |-- cModelFlux_y: double (nullable = true)
#  |-- psFlux_y: double (nullable = true)
#  |-- snr_u_cModel: double (nullable = true)
#  |-- Ixx_u: double (nullable = true)
#  |-- Ixx_z: double (nullable = true)
#  |-- I_flag: boolean (nullable = true)
#  |-- mag_u_cModel: double (nullable = true)
#  |-- psFlux_r: double (nullable = true)
#  |-- clean: boolean (nullable = true)
#  |-- cModelFlux_g: double (nullable = true)
#  |-- magerr_y_cModel: double (nullable = true)
#  |-- ra: double (nullable = true)
#  |-- cModelFlux_flag_y: boolean (nullable = true)
#  |-- tract: long (nullable = true)
#  |-- IxyPSF: double (nullable = true)
#  |-- mag_u: double (nullable = true)
#  |-- mag_y_cModel: double (nullable = true)
#  |-- parentObjectId: long (nullable = true)
#  |-- xErr: float (nullable = true)
#  |-- psFluxErr_g: double (nullable = true)
#  |-- snr_r_cModel: double (nullable = true)
#  |-- patch: string (nullable = true)
#  |-- magerr_g_cModel: double (nullable = true)
#  |-- Ixx: double (nullable = true)
#  |-- psFlux_flag_z: boolean (nullable = true)
#  |-- IxyPSF_g: double (nullable = true)
#  |-- cModelFluxErr_i: double (nullable = true)
#  |-- cModelFlux_r: double (nullable = true)
#  |-- Iyy_u: double (nullable = true)
#  |-- mag_i_cModel: double (nullable = true)
#  |-- IxyPSF_u: double (nullable = true)
#  |-- IyyPSF_i: double (nullable = true)
#  |-- I_flag_y: boolean (nullable = true)
#  |-- psFluxErr_u: double (nullable = true)
#  |-- Ixy_y: double (nullable = true)
#  |-- y: double (nullable = true)
#  |-- Ixx_y: double (nullable = true)
#  |-- IxxPSF_g: double (nullable = true)
#  |-- Ixx_g: double (nullable = true)
#  |-- cModelFlux_flag_z: boolean (nullable = true)
#  |-- I_flag_z: boolean (nullable = true)
#  |-- I_flag_r: boolean (nullable = true)
#  |-- magerr_u_cModel: double (nullable = true)
#  |-- IyyPSF_g: double (nullable = true)
#  |-- psFluxErr_z: double (nullable = true)
#  |-- cModelFluxErr_u: double (nullable = true)
#  |-- mag_i: double (nullable = true)

# %%
# Subset of columns of interest
cols = "mag_g_cModel, mag_r_cModel, mag_i_cModel"

# SQL - register first the DataFrame
df.createOrReplaceTempView("full_tract")

# Used to be g_modelfit_CModel_flux
sql_command = """
    SELECT {}
    FROM full_tract 
    WHERE 
        tract == 4636 AND
        clean AND
        magerr_g_cModel>0 AND
        magerr_g_cModel<1e16 AND
        magerr_r_cModel>0 AND
        magerr_r_cModel<1e16 AND
        magerr_i_cModel>0 AND
        magerr_i_cModel<1e16
""".format(cols)

# Execute the expression - return a DataFrame
df_sub = spark.sql(sql_command)

print(df_sub.count())
# Out:
# 129596

# %% [markdown]
# So now, we have selected what we think are stars. Let's take a look at the colors of these objects

# %%
plt.figure(figsize=(15, 15))
mag_g_cModel, mag_r_cModel, mag_i_cModel = np.transpose(df_sub.collect())
plt.hist2d(mag_g_cModel - mag_r_cModel,
           mag_r_cModel - mag_i_cModel, 
           bins=100,range=[(-1,2),(-1,2)]);
plt.xlabel('$g-r$')
plt.ylabel('$r-i$')
plt.colorbar(label='Number of objects');
plt.grid(color="w")

# %% [markdown]
# # GroupBy

# %%
df_stat=df_gal.groupBy("tract").count()

# %%
df_stat.show()
# Out:
# +-----+------+
# |tract| count|
# +-----+------+
# | 2906|761182|
# | 3452|785896|
# | 3081|828969|
# | 3640|803361|
# | 2900|814598|
# | 4028|833885|
# | 4235|791681|
# | 4636|107337|
# | 2724|   177|
# | 3634|862612|
# | 3076|819004|
# | 3636|869495|
# | 4639|845713|
# | 4859|806074|
# | 3258|836615|
# | 4436|799418|
# | 4229|861909|
# | 4034|776378|
# | 4231|834705|
# | 2908|693791|
# +-----+------+
# only showing top 20 rows

# %%
dp_stat=df_stat.toPandas()
dp_stat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 2 columns):
# tract    165 non-null int64
# count    165 non-null int64
# dtypes: int64(2)
# memory usage: 2.7 KB

# %%
indexes=np.arange(len(dp_stat))

# %%
width=0.8
fig = plt.figure(figsize=(20,6))
ax = fig.add_subplot(111)
ax.bar(indexes,dp_stat["count"].values,width,color='red')
ax.set_xticks(indexes)
ax.set_title("Number of count of extended obj per tract")
xtickNames = ax.set_xticklabels(dp_stat["tract"].values)
plt.setp(xtickNames, rotation=90, fontsize=10)
plt.yscale('log')

# %% [markdown]
# The DM stack includes functionality to get the tract and patch number corresponding to a certain position `(RA,DEC)`. However, it is out of the scope of this tutorial.

# %% [markdown]
# Apache Spark provides `filter` mechanisms, which you can use to speed up data access if you only need a certain chunks of the dataset.
# For the object catalog, the chunks are broken into `tract` and `patch`, and hence those are the `filters` you can use:

# %%
idx=0
for the_tract in dp_stat["tract"].values:
    selection_name = "tract == {}".format(the_tract)

    # Retrieve the ra,dec coordinates of all sources within tract number 4430
    data = df_gal.select('ra', 'dec').where(selection_name).collect()
    #data = df.select('ra', 'dec').collect()
    
    print("======= tract {} ================".format(the_tract))
    #data.describe().show()

    if dp_stat["count"].values[idx]>1e4:
    
        # `collect` returns list of list[ra, dec], so for 
        # plotting purpose we tranpose the output:
        ra, dec = np.transpose(data)

        # Plot a 2d histogram of sources
        plt.figure(figsize=(10,7))
        plt.hist2d(ra, dec, 100)
        plt.gca().set_aspect('equal')
        plt.colorbar(label='Number of objects')
        plt.xlabel('RA [deg]')
        plt.ylabel('dec [deg]');
        plt.title("tract = {}".format(the_tract))
        plt.show()
        
    idx+=1
    if idx>2:
        break
# Out:
# ======= tract 2906 ================
# ======= tract 3452 ================
# ======= tract 3081 ================

# %%
pd_ang2pix = pandas_udf(Ang2Pix_func, returnType=IntegerType())
df_gal_healpix = df_gal.withColumn("ihealpix",pd_ang2pix(df_gal["ra"],df_gal["dec"]))

# %%
df_gal_healpix.printSchema()
# Out:
# root
#  |-- mag_z: double (nullable = true)
#  |-- psFluxErr_y: double (nullable = true)
#  |-- cModelFlux_flag_r: boolean (nullable = true)
#  |-- IxxPSF_i: double (nullable = true)
#  |-- snr_g_cModel: double (nullable = true)
#  |-- psFlux_u: double (nullable = true)
#  |-- psFluxErr_r: double (nullable = true)
#  |-- IxxPSF_u: double (nullable = true)
#  |-- magerr_r: double (nullable = true)
#  |-- psFlux_i: double (nullable = true)
#  |-- cModelFluxErr_z: double (nullable = true)
#  |-- psFlux_flag_y: boolean (nullable = true)
#  |-- x: double (nullable = true)
#  |-- cModelFlux_flag_i: boolean (nullable = true)
#  |-- I_flag_g: boolean (nullable = true)
#  |-- Iyy_y: double (nullable = true)
#  |-- mag_g_cModel: double (nullable = true)
#  |-- psf_fwhm_g: double (nullable = true)
#  |-- IxyPSF_y: double (nullable = true)
#  |-- Iyy_g: double (nullable = true)
#  |-- psf_fwhm_y: double (nullable = true)
#  |-- xy_flag: boolean (nullable = true)
#  |-- cModelFlux_i: double (nullable = true)
#  |-- Iyy_i: double (nullable = true)
#  |-- magerr_z: double (nullable = true)
#  |-- mag_y: double (nullable = true)
#  |-- magerr_i: double (nullable = true)
#  |-- snr_z_cModel: double (nullable = true)
#  |-- good: boolean (nullable = true)
#  |-- IxyPSF_z: double (nullable = true)
#  |-- cModelFluxErr_r: double (nullable = true)
#  |-- cModelFluxErr_g: double (nullable = true)
#  |-- psFlux_g: double (nullable = true)
#  |-- IxyPSF_i: double (nullable = true)
#  |-- Iyy_z: double (nullable = true)
#  |-- psFlux_z: double (nullable = true)
#  |-- IxxPSF_y: double (nullable = true)
#  |-- Ixy_r: double (nullable = true)
#  |-- magerr_g: double (nullable = true)
#  |-- extendedness: double (nullable = true)
#  |-- blendedness: double (nullable = true)
#  |-- IxyPSF_r: double (nullable = true)
#  |-- Ixx_i: double (nullable = true)
#  |-- IyyPSF_u: double (nullable = true)
#  |-- Ixx_r: double (nullable = true)
#  |-- IxxPSF: double (nullable = true)
#  |-- Iyy_r: double (nullable = true)
#  |-- Ixy_g: double (nullable = true)
#  |-- dec: double (nullable = true)
#  |-- IyyPSF: double (nullable = true)
#  |-- cModelFlux_flag_u: boolean (nullable = true)
#  |-- psFluxErr_i: double (nullable = true)
#  |-- Ixy_i: double (nullable = true)
#  |-- objectId: long (nullable = true)
#  |-- magerr_r_cModel: double (nullable = true)
#  |-- mag_r: double (nullable = true)
#  |-- magerr_u: double (nullable = true)
#  |-- mag_z_cModel: double (nullable = true)
#  |-- Ixy: double (nullable = true)
#  |-- yErr: float (nullable = true)
#  |-- I_flag_u: boolean (nullable = true)
#  |-- psFlux_flag_g: boolean (nullable = true)
#  |-- psf_fwhm_u: double (nullable = true)
#  |-- IyyPSF_z: double (nullable = true)
#  |-- psNdata: float (nullable = true)
#  |-- mag_r_cModel: double (nullable = true)
#  |-- IyyPSF_y: double (nullable = true)
#  |-- Ixy_z: double (nullable = true)
#  |-- I_flag_i: boolean (nullable = true)
#  |-- snr_i_cModel: double (nullable = true)
#  |-- cModelFlux_z: double (nullable = true)
#  |-- magerr_y: double (nullable = true)
#  |-- psf_fwhm_r: double (nullable = true)
#  |-- magerr_i_cModel: double (nullable = true)
#  |-- Ixy_u: double (nullable = true)
#  |-- psf_fwhm_i: double (nullable = true)
#  |-- cModelFluxErr_y: double (nullable = true)
#  |-- psf_fwhm_z: double (nullable = true)
#  |-- psFlux_flag_r: boolean (nullable = true)
#  |-- psFlux_flag_i: boolean (nullable = true)
#  |-- snr_y_cModel: double (nullable = true)
#  |-- IxxPSF_r: double (nullable = true)
#  |-- Iyy: double (nullable = true)
#  |-- mag_g: double (nullable = true)
#  |-- IxxPSF_z: double (nullable = true)
#  |-- magerr_z_cModel: double (nullable = true)
#  |-- psFlux_flag_u: boolean (nullable = true)
#  |-- cModelFlux_u: double (nullable = true)
#  |-- IyyPSF_r: double (nullable = true)
#  |-- cModelFlux_flag_g: boolean (nullable = true)
#  |-- cModelFlux_y: double (nullable = true)
#  |-- psFlux_y: double (nullable = true)
#  |-- snr_u_cModel: double (nullable = true)
#  |-- Ixx_u: double (nullable = true)
#  |-- Ixx_z: double (nullable = true)
#  |-- I_flag: boolean (nullable = true)
#  |-- mag_u_cModel: double (nullable = true)
#  |-- psFlux_r: double (nullable = true)
#  |-- clean: boolean (nullable = true)
#  |-- cModelFlux_g: double (nullable = true)
#  |-- magerr_y_cModel: double (nullable = true)
#  |-- ra: double (nullable = true)
#  |-- cModelFlux_flag_y: boolean (nullable = true)
#  |-- tract: long (nullable = true)
#  |-- IxyPSF: double (nullable = true)
#  |-- mag_u: double (nullable = true)
#  |-- mag_y_cModel: double (nullable = true)
#  |-- parentObjectId: long (nullable = true)
#  |-- xErr: float (nullable = true)
#  |-- psFluxErr_g: double (nullable = true)
#  |-- snr_r_cModel: double (nullable = true)
#  |-- patch: string (nullable = true)
#  |-- magerr_g_cModel: double (nullable = true)
#  |-- Ixx: double (nullable = true)
#  |-- psFlux_flag_z: boolean (nullable = true)
#  |-- IxyPSF_g: double (nullable = true)
#  |-- cModelFluxErr_i: double (nullable = true)
#  |-- cModelFlux_r: double (nullable = true)
#  |-- Iyy_u: double (nullable = true)
#  |-- mag_i_cModel: double (nullable = true)
#  |-- IxyPSF_u: double (nullable = true)
#  |-- IyyPSF_i: double (nullable = true)
#  |-- I_flag_y: boolean (nullable = true)
#  |-- psFluxErr_u: double (nullable = true)
#  |-- Ixy_y: double (nullable = true)
#  |-- y: double (nullable = true)
#  |-- Ixx_y: double (nullable = true)
#  |-- IxxPSF_g: double (nullable = true)
#  |-- Ixx_g: double (nullable = true)
#  |-- cModelFlux_flag_z: boolean (nullable = true)
#  |-- I_flag_z: boolean (nullable = true)
#  |-- I_flag_r: boolean (nullable = true)
#  |-- magerr_u_cModel: double (nullable = true)
#  |-- IyyPSF_g: double (nullable = true)
#  |-- psFluxErr_z: double (nullable = true)
#  |-- cModelFluxErr_u: double (nullable = true)
#  |-- mag_i: double (nullable = true)
#  |-- ihealpix: integer (nullable = true)

# %%
df_gal_healpix_small=df_gal_healpix.select('ra','dec','ihealpix')

# %%
df_gal_healpix_small.describe().show()
# Out:
# +-------+------------------+-------------------+------------------+
# |summary|                ra|                dec|          ihealpix|
# +-------+------------------+-------------------+------------------+
# |  count|         111836547|          111836547|         111836547|
# |   mean| 61.98946569360291|-36.047891658732965| 2494322.522756921|
# | stddev|6.2149644200265834|  4.947714127551157|109736.78864275615|
# |    min| 49.49254691350636|-44.642587097415955|           2282843|
# |    max| 74.21783862260499|-26.935087554628794|           2678580|
# +-------+------------------+-------------------+------------------+

# %%
m=df_gal_healpix_small.groupBy('ihealpix').count()
m.show(5)
# Out:
# +--------+-----+
# |ihealpix|count|
# +--------+-----+
# | 2676533| 1640|
# | 2658992| 5307|
# | 2658975| 4519|
# | 2672755| 4699|
# | 2651119| 5310|
# +--------+-----+
# only showing top 5 rows

# %%
#m.orderBy('ihealpix', ascending=True).show(10)

# %%
# get to python world (to Pandas) : 
# note that here is the action (lazy evaluation so far)
p=m.toPandas()
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23427 entries, 0 to 23426
# Data columns (total 2 columns):
# ihealpix    23427 non-null int32
# count       23427 non-null int64
# dtypes: int32(1), int64(1)
# memory usage: 274.7 KB

# %%
p
# Out:
#        ihealpix  count
# 0       2632926   4664
# 1       2620711   5039
# 2       2645105   4650
# 3       2635048   4631
# 4       2596159   5057
# ...         ...    ...
# 23422   2440483     64
# 23423   2678492     14
# 23424   2487710     81
# 23425   2678493     35
# 23426   2678534      2
#
# [23427 rows x 2 columns]

# %%
# the following doesn't has anything to do with spark (only Healpix)
hpMap = np.zeros(hp.nside2npix(nside))
#fill the map from the pandas object
hpMap[p['ihealpix'].values]=p['count'].values
#plot using standard healpy function
hp.mollview(hpMap,cmap="jet")
hp.graticule(color='white')
# Out:
# /opt/anaconda3-5.2.0/lib/python3.6/site-packages/healpy/projaxes.py:543: UserWarning: 0.0 180.0 -180.0 180.0
#   pmin / dtor, pmax / dtor, mmin / dtor, mmax / dtor
# /opt/anaconda3-5.2.0/lib/python3.6/site-packages/healpy/projaxes.py:658: UserWarning: The interval between parallels is 30 deg -0.00'.
#   vdeg, varcmin
# /opt/anaconda3-5.2.0/lib/python3.6/site-packages/healpy/projaxes.py:666: UserWarning: The interval between meridians is 30 deg -0.00'.
#   vdeg, varcmin

# %%
plt.hist(hpMap,bins=int(100))
plt.yscale('log')
plt.show()

# %%
cl = hp.anafast(hpMap)
ell = np.arange(len(cl))

# %%
plt.plot(ell,cl,"ro")
plt.yscale('log')
plt.xlabel("$\ell$")
plt.ylabel("$C_\ell$")
plt.title("{} : $C_\ell$ by healpix/anafast".format("DC2Run2.2i"))
# Out:
# Text(0.5, 1.0, 'DC2Run2.2i : $C_\\ell$ by healpix/anafast')

# %%
lmax
# Out:
# 1536

# %%
hpMap.shape
# Out:
# (3145728,)
